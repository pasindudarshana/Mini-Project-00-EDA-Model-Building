# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 1)) (2.3.2)
# Requirement already satisfied: pandas in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 2)) (2.3.1)
# Requirement already satisfied: scikit-learn in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: imbalanced-learn in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 4)) (0.13.0)
# Requirement already satisfied: matplotlib in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 5)) (3.10.5)
# Requirement already satisfied: seaborn in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: plotly in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 7)) (6.2.0)
# Requirement already satisfied: joblib in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: pyyaml in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 9)) (6.0.2)
# Requirement already satisfied: python-dotenv in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 10)) (1.1.1)
# Requirement already satisfied: pandas-profiling in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: statsmodels in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 12)) (0.14.5)
# Requirement already satisfied: ipython in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from -r requirements.txt (line 13)) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from imbalanced-learn->-r requirements.txt (line 4)) (0.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from plotly->-r requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (2.11.7)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: visions==0.7.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (0.12.5)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (0.1.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (2.32.4)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pandas-profiling->-r requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (3.5)
# Requirement already satisfied: bottleneck in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: multimethod==1.4 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from visions==0.7.1->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (1.4)
# Requirement already satisfied: imagehash in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (4.3.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from statsmodels->-r requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: colorama in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from ipython->-r requirements.txt (line 13)) (4.14.1)
# Requirement already satisfied: wcwidth in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->-r requirements.txt (line 13)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 13)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from jinja2>=2.11.1->pandas-profiling->-r requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pydantic>=1.8.1->pandas-profiling->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pydantic>=1.8.1->pandas-profiling->-r requirements.txt (line 11)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from pydantic>=1.8.1->pandas-profiling->-r requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 11)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 11)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from requests>=2.24.0->pandas-profiling->-r requirements.txt (line 11)) (2025.7.14)
# Requirement already satisfied: PyWavelets in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from imagehash->visions[type_image_path]==0.7.1->pandas-profiling->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from stack_data->ipython->-r requirements.txt (line 13)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from stack_data->ipython->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\pasin\anaconda3\envs\bprmls\lib\site-packages (from stack_data->ipython->-r requirements.txt (line 13)) (0.2.3)

# %% [markdown]
# ### 1. Import Dependencies

# %%
import os
from enum import Enum
import seaborn as sns
from pydantic import BaseModel
from dotenv import load_dotenv
import numpy as np # alias
import openai, groq
import pandas as pd # alias

load_dotenv()
# Out:
# False

# %%
os.getcwd()
# Out:
# 'd:\\MY FILES\\Projects\\Building AI Products\\Mini-Project-00---EDA-Model-Building'

# %% [markdown]
# ### 2. Basic Information

# %%
df = pd.read_csv('data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head(15)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# 11  7469-LKBCI    Male              0      No         No      16          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
#
#        MultipleLines InternetService       OnlineSecurity  ...  \
# 0   No phone service             DSL                   No  ...
# 1                 No             DSL                  Yes  ...
# 2                 No             DSL                  Yes  ...
# 3   No phone service             DSL                  Yes  ...
# 4                 No     Fiber optic                   No  ...
# 5                Yes     Fiber optic                   No  ...
# 6                Yes     Fiber optic                   No  ...
# 7   No phone service             DSL                  Yes  ...
# 8                Yes     Fiber optic                   No  ...
# 9                 No             DSL                  Yes  ...
# 10                No             DSL                  Yes  ...
# 11                No              No  No internet service  ...
# 12               Yes     Fiber optic                   No  ...
# 13               Yes     Fiber optic                   No  ...
# 14                No     Fiber optic                  Yes  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 0                    No                   No                   No
# 1                   Yes                   No                   No
# 2                    No                   No                   No
# 3                   Yes                  Yes                   No
# 4                    No                   No                   No
# 5                   Yes                   No                  Yes
# 6                    No                   No                  Yes
# 7                    No                   No                   No
# 8                   Yes                  Yes                  Yes
# 9                    No                   No                   No
# 10                   No                   No                   No
# 11  No internet service  No internet service  No internet service
# 12                  Yes                   No                  Yes
# 13                  Yes                   No                  Yes
# 14                  Yes                  Yes                  Yes
#
#         StreamingMovies        Contract PaperlessBilling  \
# 0                    No  Month-to-month              Yes
# 1                    No        One year               No
# 2                    No  Month-to-month              Yes
# 3                    No        One year               No
# 4                    No  Month-to-month              Yes
# 5                   Yes  Month-to-month              Yes
# 6                    No  Month-to-month              Yes
# 7                    No  Month-to-month               No
# 8                   Yes  Month-to-month              Yes
# 9                    No        One year               No
# 10                   No  Month-to-month              Yes
# 11  No internet service        Two year               No
# 12                  Yes        One year               No
# 13                  Yes  Month-to-month              Yes
# 14                  Yes  Month-to-month              Yes
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 0            Electronic check          29.85         29.85    No
# 1                Mailed check          56.95        1889.5    No
# 2                Mailed check          53.85        108.15   Yes
# 3   Bank transfer (automatic)          42.30       1840.75    No
# 4            Electronic check          70.70        151.65   Yes
# 5            Electronic check          99.65         820.5   Yes
# 6     Credit card (automatic)          89.10        1949.4    No
# 7                Mailed check          29.75         301.9    No
# 8            Electronic check         104.80       3046.05   Yes
# 9   Bank transfer (automatic)          56.15       3487.95    No
# 10               Mailed check          49.95        587.45    No
# 11    Credit card (automatic)          18.95         326.8    No
# 12    Credit card (automatic)         100.35        5681.1    No
# 13  Bank transfer (automatic)         103.70        5036.3   Yes
# 14           Electronic check         105.50       2686.05    No
#
# [15 rows x 21 columns]

# %% [markdown]
# NaN = Not a Number

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0            False          False            False           False  ...
# 1            False          False            False           False  ...
# 2            False          False            False           False  ...
# 3            False          False            False           False  ...
# 4            False          False            False           False  ...
# ...            ...            ...              ...             ...  ...
# 7038         False          False            False           False  ...
# 7039         False          False            False           False  ...
# 7040         False          False            False           False  ...
# 7041         False          False            False           False  ...
# 7042         False          False            False           False  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                False        False        False            False     False
# 1                False        False        False            False     False
# 2                False        False        False            False     False
# 3                False        False        False            False     False
# 4                False        False        False            False     False
# ...                ...          ...          ...              ...       ...
# 7038             False        False        False            False     False
# 7039             False        False        False            False     False
# 7040             False        False        False            False     False
# 7041             False        False        False            False     False
# 7042             False        False        False            False     False
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 0                False          False           False         False  False
# 1                False          False           False         False  False
# 2                False          False           False         False  False
# 3                False          False           False         False  False
# 4                False          False           False         False  False
# ...                ...            ...             ...           ...    ...
# 7038             False          False           False         False  False
# 7039             False          False           False         False  False
# 7040             False          False           False         False  False
# 7041             False          False           False         False  False
# 7042             False          False           False         False  False
#
# [7043 rows x 21 columns]

# %%
# get null values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### 3. Handle Missing Values

# %% [markdown]
# #### 3.1 Deletion

# %% [markdown]
# **axis = 1** -> check each column and drop if atleast 1 null value consists of <br/>
# **axis = 0** -> check each row and drop if atleast 1 null value consists of

# %% [markdown]
# #### 3.2 Imputation

# %% [markdown]
# The possible ways to do this are:
#
# - Filling the missing data with the mean or median value if it’s a numerical variable.
# - Filling the missing data with mode if it’s a categorical value.
# - Filling the numerical value with 0 or -999, or some other number that will not occur in the data. This can be done so that the machine can recognize that the data is not real or is different.
# - Filling the categorical value with a new type for the missing values.

# %%
# Replace empty strings or whitespaces with NaN first
df['TotalCharges'] = df['TotalCharges'].replace(r'^\s*$', pd.NA, regex=True)

# Convert to numeric, invalid parsing will become NaN
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# Fill NaNs with 0
df['TotalCharges'] = df['TotalCharges'].fillna(0)

# Check
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_impute = df.copy()

# %%
df_impute = df_impute.drop(
                             columns=[
                                    'customerID'
                                    ]
                            )
df_impute.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
# get null values
df_impute.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_impute.to_csv(
                'data/processed/ChurnModelling_Missing_Values_Handled.csv', 
                index=False
                )
